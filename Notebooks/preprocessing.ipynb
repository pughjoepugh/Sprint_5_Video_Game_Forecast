# %% [markdown]
# ### Video Game Sales Forecast
# ___
# The goal of this project is to uncover advertising strategies for a global video game retailer. We have historical video game sales data for many platforms and areas of the world.
#
# In this notebook we will load and explore the data developing a plan of action to prepare this data for exploration.
#
# #### Pre-processing data
# ___
# Step 1:<br>
#     - Load data and take a look at what we are working with.<br>
#     - Personalize Pandas settings<br>
#     <br>
# Step 2:<br>
#     - Change column names to lowercase convention, removing spaces if needed<br>
#     - Deal with duplicates, complete and partial, then drop them<br>
#     <br>
# Step 3:<br>
#     - Handle missing values<br>
#     - How many, distribution across columns/ rows<br>
#     - Drop rows with too many missing values<br>
#     - Fill missing values with placeholders<br>
#     - Replace/ update current placeholder missing values<br>
#     <br>
# Step 4:<br>
#     - Standardize spelling conventions, making them lowercase, updating values as needed<br>
#     - Ratings, genre, name columns<br>
#     - Make critic and user score the same range<br>
#     <br>
# Step 5:<br>
#     - Feature engineering, create more data based on current values<br>
#     - Create columns: total/ global sales, brand, mobile device<br>
#     <br>
# Step 6:<br>
#     - Store processed data for Exploratory Data Analysis

# %%
# load pandas
import pandas as pd

# %%
# store data
game = pd.read_csv('../games.csv')

# %%
# take a look at our data
game.info()
game.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# Delveloping a plan:
# From the first glance our data is going to need at least several adjustments.
#
# - column names turned into lower case
# - missing values, sometimes a lot of them
# - appears that the name column has the longest data entry (physical length)

# %%
# what is the longest name string? for pandas customization
game['Name'].str.len().max()
# Out:
# 132.0

# %%
# personalize/modify pandas

# work with max rows == None but it makes scrolling annoying
pd.set_option('display.max_rows', 30)
pd.set_option('display.max_columns', None)
pd.set_option('display.precision', 4)
pd.set_option('display.max_colwidth', 132)

# %%
# updating column spellings to lower case

# create a list of column names
col_names = list(game.columns)

# convert column names to lower case, and overwrite the column names
game.columns = list(map(lambda x: x.lower(), col_names))

# %% [markdown]
# #### Duplicates
# ___
# Looking into duplicates. Search for complete duplicates, and paired unique value duplicates as well. Removing any duplicates we find.

# %%
# complete duplicates
game.duplicated().sum()
# Out:
# 0

# %%
# zero complete duplicates, how about
# paired duplicates between name and platform

# sear
test = game.duplicated(subset=['name', 'platform'], keep='last').reset_index()
test = test[test[0] == True]
dup_index = list(test['index'])
dup_index
# Out:
# [604, 659, 1190, 1745, 5972]

# %%
test = game.duplicated(subset=['name', 'platform'], keep='first').reset_index()
test = test[test[0] == True]
dup_index2 = list(test['index'])
dup_index2
# Out:
# [1591, 4127, 11715, 14244, 16230]

# %%
# remove them
game = game.drop(dup_index)

# %%
# new version
game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16710 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16709 non-null  object
#  1   platform         16710 non-null  object
#  2   year_of_release  16441 non-null  float64
#  3   genre            16709 non-null  object
#  4   na_sales         16710 non-null  float64
#  5   eu_sales         16710 non-null  float64
#  6   jp_sales         16710 non-null  float64
#  7   other_sales      16710 non-null  float64
#  8   critic_score     8133 non-null   float64
#  9   user_score       10010 non-null  object
#  10  rating           9945 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# #### Global missing values
# ___
# Look into the missing values.<br>
# How is the distribution? <br>
# Are there areas with too much missing info to be useable?<br>
# Fill missing values as needed, the goal is preserve as much data as possible<br>

# %%
# to what extent are rows missing values?
# find out how much of our data is missing a lot of values

# list for storage
totals = []

# loop through possible maximum missing values (column count)
for threshold in range(11):

    # create a dictionary:
    # key = threshold for missing values in a row
    # values = number of rows missing the threshold amount of data
    temp_dict = {threshold: len(game[game.isna().sum(axis=1) >= threshold]),
                 "% of total rows": len(game[game.isna().sum(axis=1) >= threshold])/len(game)}

    # store them
    totals.append(temp_dict)

# show them
print(totals)
# Out:
# [{0: 16710, '% of total rows': 1.0}, {1: 8836, '% of total rows': 0.528785158587672}, {2: 6765, '% of total rows': 0.40484739676840215}, {3: 6625, '% of total rows': 0.3964691801316577}, {4: 86, '% of total rows': 0.005146618791143028}, {5: 1, '% of total rows': 5.984440454817474e-05}, {6: 0, '% of total rows': 0.0}, {7: 0, '% of total rows': 0.0}, {8: 0, '% of total rows': 0.0}, {9: 0, '% of total rows': 0.0}, {10: 0, '% of total rows': 0.0}]

# %% [markdown]
# We knew there was quite a lot of missing values, but we weren't certain how they were distributed across the dataframe. ~40% have 3 missing values, but only 0.5% have 4 missing. That's a clear cut off.

# %%
# which rows have 4 missing values?

# filter for rows with at least 4 missing values
df_filtered = game[game.isna().sum(axis=1) >= 4]

df_filtered
# Out:
#                                                                      name  \
# 475                                            wwe Smackdown vs. Raw 2006
# 609                                                        Space Invaders
# 1301                                                       Triple Play 99
# 1506                                                            Adventure
# 1585                                                               Combat
# 2010                                                 Donkey Kong Land III
# 2106                                                       Air-Sea Battle
# 2361                                                        Rhythm Heaven
# 2572                                       PES 2009: Pro Evolution Soccer
# 2773                                                  WarioWare: Twisted!
# 3187                                                     Monster Hunter 2
# 3883                                                        Fishing Derby
# 4132                                                               Karate
# 4220                                                         Circus Atari
# 4337                                Maze Craze: A Game of Cops 'n Robbers
# 4437                                                       Super Breakout
# 5041                                                              Hangman
# 5194                            Cubix Robots for Everyone: Clash 'n' Bash
# 5294                        Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)
# 5492                                                          Custom Robo
# 5642                                                             Dragster
# 5800                                                         Slot Machine
# 5874                                  Harvest Moon: The Tale of Two Towns
# 6255                 The Legend of Zelda: The Minish Cap(weekly JP sales)
# 6266                                                             Indy 500
# 6299                                                         Flag Capture
# 6899                                     Danganronpa: Trigger Happy Havoc
# 6954                                                              Jet X20
# 7353                                                      Ghostbusters II
# 7354                                                         Breakaway IV
# 7387                                                         Move Fitness
# 7391                       Valkyria Chronicles III: Unrecorded Chronicles
# 7605                                                           Famista 64
# 8364                                                 Sword of the Samurai
# 8740                                                             Home Run
# 9119                                                     Our House Party!
# 9151                                                WCW Backstage Assault
# 9516                                           Nintendo Puzzle Collection
# 9738   Super Robot Wars OG Saga: Masou Kishin II - Revelation of Evil God
# 9761                                       Saru! Get You! Million Monkeys
# 10258                                                             GiFTPiA
# 10317                                                      Happy Feet Two
# 10486                              Atsumare! Power Pro Kun no DS Koushien
# 10764                                           Luminous Arc 2 (JP sales)
# 10790                                                      Happy Feet Two
# 11000                                                         Demon Chaos
# 11092                                        Action Man-Operation Extreme
# 11433                                            Zero: Tsukihami no Kamen
# 11622                                                      Happy Feet Two
# 11790                    Mega Man Battle Network: Operation Shooting Star
# 12235                                      National Geographic Challenge!
# 12524                                                Chou Soujuu Mecha MG
# 12568                        Prinny: Can I Really Be The Hero? (US sales)
# 12734                                        Mobile Ops: The One Year War
# 13060                                      Captain America: Super Soldier
# 13317                                      Monster Hunter Frontier Online
# 13647                       The History Channel: Great Battles - Medieval
# 13711                                           B.L.U.E.: Legend of Water
# 13929                                                     Sega Rally 2006
# 14105                                                  Half-Minute Hero 2
# 14126                                                        Housekeeping
# 14244                                                                 NaN
# 14325                                                Beyond the Labyrinth
# 14350                                                 Bikkuriman Daijiten
# 14369                                  Majesty 2: The Fantasy Kingdom Sim
# 14449                                    Fullmetal Alchemist: Brotherhood
# 14597                               Samurai Spirits: Tenkaichi Kenkakuden
# 14749                                Tom and Jerry in War of the Whiskers
# 14931                       The King of Fighters: Maximum Impact - Maniax
# 14950                             Combat Wings: The Great Battles of WWII
# 15022      Umineko no Naku Koro ni San: Shinjitsu to Gensou no Yasoukyoku
# 15079                                               Payout Poker & Casino
# 15081                                         Wii de Asobu: Metroid Prime
# 15119                                          Legacy of Ys: Books I & II
# 15338                                                        Mario Tennis
# 15557                          Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)
# 15675                                          Cabela's Alaskan Adventure
# 15704                          Writing and Speaking Beautiful Japanese DS
# 15795                             Shonen Jump's Yu-Gi-Oh! GX Card Almanac
# 15953                                   PDC World Championship Darts 2008
# 15998                                                         Jet Impulse
# 16059                                              Dance! It's Your Stage
# 16079                                               Football Manager 2007
# 16293                              AKB1/48: Idol to Guam de Koishitara...
# 16348                                        Agarest Senki: Re-appearance
# 16458                                         Hakuouki: Shinsengumi Kitan
#
#       platform  year_of_release         genre  na_sales  eu_sales  jp_sales  \
# 475        PS2              NaN      Fighting      1.57      1.02      0.00
# 609       2600              NaN       Shooter      2.36      0.14      0.00
# 1301        PS              NaN        Sports      0.81      0.55      0.00
# 1506      2600              NaN     Adventure      1.21      0.08      0.00
# 1585      2600              NaN        Action      1.17      0.07      0.00
# 2010        GB              NaN      Platform      0.68      0.31      0.00
# 2106      2600              NaN       Shooter      0.91      0.06      0.00
# 2361       Wii              NaN          Misc      0.11      0.00      0.77
# 2572       PSP              NaN        Sports      0.04      0.33      0.26
# 2773       GBA              NaN        Puzzle      0.16      0.06      0.50
# 3187       PS2              NaN  Role-Playing      0.00      0.00      0.63
# 3883      2600              NaN        Sports      0.48      0.03      0.00
# 4132      2600              NaN      Fighting      0.44      0.03      0.00
# 4220      2600              NaN        Action      0.43      0.03      0.00
# 4337      2600              NaN        Action      0.42      0.02      0.00
# 4437      2600              NaN        Puzzle      0.41      0.03      0.00
# 5041      2600              NaN        Puzzle      0.35      0.02      0.00
# 5194       GBA              NaN        Action      0.26      0.10      0.00
# 5294       Wii              NaN        Action      0.15      0.05      0.14
# 5492       N64              NaN  Role-Playing      0.00      0.00      0.29
# 5642      2600              NaN        Racing      0.30      0.02      0.00
# 5800      2600              NaN        Action      0.29      0.02      0.00
# 5874       3DS              NaN    Simulation      0.28      0.00      0.00
# 6255       GBA              NaN        Action      0.00      0.00      0.27
# 6266      2600              NaN        Racing      0.26      0.01      0.00
# 6299      2600              NaN        Action      0.25      0.02      0.00
# 6899       PSP              NaN          Misc      0.00      0.00      0.24
# 6954       PS2              NaN        Racing      0.11      0.09      0.00
# 7353      2600              NaN        Action      0.20      0.01      0.00
# 7354      2600              NaN        Puzzle      0.20      0.01      0.00
# 7387       PS3              NaN        Sports      0.00      0.16      0.00
# 7391       PSP              NaN      Strategy      0.00      0.00      0.21
# 7605       N64              NaN        Sports      0.00      0.00      0.17
# 8364       PS2              NaN      Fighting      0.00      0.00      0.17
# 8740      2600              NaN        Sports      0.14      0.01      0.00
# 9119       Wii              NaN    Simulation      0.13      0.00      0.00
# 9151       N64              NaN        Action      0.11      0.03      0.00
# 9516        GC              NaN        Puzzle      0.00      0.00      0.13
# 9738       PSP              NaN      Strategy      0.00      0.00      0.12
# 9761       PS2              NaN      Platform      0.00      0.00      0.12
# 10258       GC              NaN  Role-Playing      0.00      0.00      0.11
# 10317      PS3              NaN        Action      0.09      0.00      0.00
# 10486       DS              NaN        Sports      0.00      0.00      0.10
# 10764       DS              NaN  Role-Playing      0.00      0.00      0.10
# 10790     X360              NaN        Action      0.08      0.01      0.00
# 11000      PS2              NaN        Action      0.00      0.00      0.09
# 11092       PS              NaN        Action      0.05      0.03      0.00
# 11433      Wii              NaN        Action      0.00      0.00      0.08
# 11622      Wii              NaN        Action      0.06      0.01      0.00
# 11790       DS              NaN  Role-Playing      0.00      0.00      0.07
# 12235     X360              NaN          Misc      0.06      0.00      0.00
# 12524       DS              NaN    Simulation      0.00      0.00      0.06
# 12568      PSP              NaN        Action      0.06      0.00      0.00
# 12734     X360              NaN    Simulation      0.00      0.00      0.06
# 13060       DS              NaN        Action      0.05      0.00      0.00
# 13317      PS3              NaN  Role-Playing      0.00      0.00      0.05
# 13647      PS3              NaN      Strategy      0.00      0.03      0.00
# 13711       PS              NaN     Adventure      0.00      0.00      0.04
# 13929      PS2              NaN        Racing      0.00      0.00      0.04
# 14105      PSP              NaN  Role-Playing      0.00      0.00      0.04
# 14126       DS              NaN        Action      0.00      0.00      0.04
# 14244      GEN           1993.0           NaN      0.00      0.00      0.03
# 14325      3DS              NaN  Role-Playing      0.00      0.00      0.03
# 14350       DS              NaN          Misc      0.00      0.00      0.03
# 14369     X360              NaN    Simulation      0.03      0.00      0.00
# 14449      PSP              NaN        Action      0.00      0.00      0.03
# 14597      PS2              NaN      Fighting      0.00      0.00      0.03
# 14749       XB              NaN      Fighting      0.02      0.01      0.00
# 14931       XB              NaN      Fighting      0.02      0.01      0.00
# 14950      Wii              NaN    Simulation      0.02      0.00      0.00
# 15022      PS3              NaN     Adventure      0.00      0.00      0.02
# 15079      PSP              NaN          Misc      0.02      0.00      0.00
# 15081      Wii              NaN       Shooter      0.00      0.00      0.02
# 15119       DS              NaN  Role-Playing      0.02      0.00      0.00
# 15338      3DS              NaN        Sports      0.00      0.00      0.02
# 15557      Wii              NaN        Racing      0.00      0.00      0.02
# 15675      PS2              NaN        Sports      0.01      0.01      0.00
# 15704       DS              NaN          Misc      0.00      0.00      0.02
# 15795       DS              NaN          Misc      0.00      0.00      0.02
# 15953       DS              NaN        Sports      0.01      0.00      0.00
# 15998       DS              NaN    Simulation      0.00      0.00      0.02
# 16059      Wii              NaN          Misc      0.00      0.01      0.00
# 16079     X360              NaN        Sports      0.00      0.01      0.00
# 16293     X360              NaN          Misc      0.00      0.00      0.01
# 16348      PS3              NaN  Role-Playing      0.00      0.00      0.01
# 16458      PS3              NaN     Adventure      0.01      0.00      0.00
#
#        other_sales  critic_score user_score rating
# 475           0.41           NaN        NaN    NaN
# 609           0.03           NaN        NaN    NaN
# 1301          0.10           NaN        NaN    NaN
# 1506          0.01           NaN        NaN    NaN
# 1585          0.01           NaN        NaN    NaN
# 2010          0.04           NaN        NaN    NaN
# 2106          0.01           NaN        NaN    NaN
# 2361          0.01           NaN        NaN    NaN
# 2572          0.17           NaN        NaN    NaN
# 2773          0.02           NaN        NaN    NaN
# 3187          0.00           NaN        NaN    NaN
# 3883          0.01           NaN        NaN    NaN
# 4132          0.00           NaN        NaN    NaN
# 4220          0.00           NaN        NaN    NaN
# 4337          0.00           NaN        NaN    NaN
# 4437          0.00           NaN        NaN    NaN
# 5041          0.00           NaN        NaN    NaN
# 5194          0.01           NaN        NaN    NaN
# 5294          0.01           NaN        NaN    NaN
# 5492          0.04           NaN        NaN    NaN
# 5642          0.00           NaN        NaN    NaN
# 5800          0.00           NaN        NaN    NaN
# 5874          0.02           NaN        NaN    NaN
# 6255          0.01           NaN        NaN    NaN
# 6266          0.00           NaN        NaN    NaN
# 6299          0.00           NaN        NaN    NaN
# 6899          0.00           NaN        NaN    NaN
# 6954          0.03           NaN        NaN    NaN
# 7353          0.00           NaN        NaN    NaN
# 7354          0.00           NaN        NaN    NaN
# 7387          0.05           NaN        NaN    NaN
# 7391          0.00           NaN        NaN    NaN
# 7605          0.03           NaN        NaN    NaN
# 8364          0.00           NaN        NaN    NaN
# 8740          0.00           NaN        NaN    NaN
# 9119          0.01           NaN        NaN    NaN
# 9151          0.00           NaN        NaN    NaN
# 9516          0.00           NaN        NaN    NaN
# 9738          0.00           NaN        NaN    NaN
# 9761          0.00           NaN        NaN    NaN
# 10258         0.00           NaN        NaN    NaN
# 10317         0.01           NaN        NaN    NaN
# 10486         0.00           NaN        NaN    NaN
# 10764         0.00           NaN        NaN    NaN
# 10790         0.01           NaN        NaN    NaN
# 11000         0.00           NaN        NaN    NaN
# 11092         0.01           NaN        NaN    NaN
# 11433         0.00           NaN        NaN    NaN
# 11622         0.01           NaN        NaN    NaN
# 11790         0.00           NaN        NaN    NaN
# 12235         0.00           NaN        NaN    NaN
# 12524         0.00           NaN        NaN    NaN
# 12568         0.00           NaN        NaN    NaN
# 12734         0.00           NaN        NaN    NaN
# 13060         0.00           NaN        NaN    NaN
# 13317         0.00           NaN        NaN    NaN
# 13647         0.01           NaN        NaN    NaN
# 13711         0.00           NaN        NaN    NaN
# 13929         0.00           NaN        NaN    NaN
# 14105         0.00           NaN        NaN    NaN
# 14126         0.00           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN
# 14325         0.00           NaN        NaN    NaN
# 14350         0.00           NaN        NaN    NaN
# 14369         0.00           NaN        NaN    NaN
# 14449         0.00           NaN        NaN    NaN
# 14597         0.00           NaN        NaN    NaN
# 14749         0.00           NaN        NaN    NaN
# 14931         0.00           NaN        NaN    NaN
# 14950         0.00           NaN        NaN    NaN
# 15022         0.00           NaN        NaN    NaN
# 15079         0.00           NaN        NaN    NaN
# 15081         0.00           NaN        NaN    NaN
# 15119         0.00           NaN        NaN    NaN
# 15338         0.00           NaN        NaN    NaN
# 15557         0.00           NaN        NaN    NaN
# 15675         0.00           NaN        NaN    NaN
# 15704         0.00           NaN        NaN    NaN
# 15795         0.00           NaN        NaN    NaN
# 15953         0.00           NaN        NaN    NaN
# 15998         0.00           NaN        NaN    NaN
# 16059         0.00           NaN        NaN    NaN
# 16079         0.00           NaN        NaN    NaN
# 16293         0.00           NaN        NaN    NaN
# 16348         0.00           NaN        NaN    NaN
# 16458         0.00           NaN        NaN    NaN

# %% [markdown]
# thoughts
# ___
# All of these are missing the score/ ratings (3 columns) and then the release year (except the weird no names)
#
# This data actually isn't that bad, so we won't simply drop it. (maybe? I don't know how I will utilize the ratings yet)
#
# Other insight: if the video game had any meaningful sales it was on the atari 2600. Atari data might get dropped because we won't be advertising for super old video games, and the sales numbers are adjusted for inflation? If they are adjusted then they are quite low. If they aren't adjusted they won't be able to relate to modern sales figures.
#
# That will get settled later.
#
# For now let's get rid of the columns missing 5 values.

# %%
# drop rows missing at least 5 values
game = game[game.isna().sum(axis=1) < 5]

# %% [markdown]
# #### Spelling conventions
# ___
# Missing values have been removed, time to convert to lowercase, remove spaces if needed, standardize column values, rename video game platforms

# %%
# rating column still has a number of missing values
game['rating'].value_counts(dropna=False)
# Out:
# rating
# NaN     6764
# E       3989
# T       2959
# M       1563
# E10+    1419
# EC         8
# K-A        3
# RP         3
# AO         1
# Name: count, dtype: int64

# %%
# update the values in the rating column while handling the missing values

# fill na's with na
game['rating'] = game['rating'].fillna('na')

# build a dictionary to rename rating column
name_dict = {'E': 'everyone',
             'T': 'teen',
             'M': 'mature',
             'E10+': 'everyone_over_ten',
             'EC': 'early childhood',
             'K-A': 'everyone',
             'RP': 'rating_pending',
             'AO': 'adults only',
             }

# replace the old values with new values
game['rating'] = game['rating'].replace(name_dict)

# %%
# convert the values to lowercase

# create a list of 'name' column
col_value = list(game['name'])

# replace old name with new name
game.name = list(map(lambda x: x.lower(), col_value))

# 'platform' column
col_value = list(game.platform)
game.platform = list(map(lambda x: x.lower(), col_value))

# 'genre' column
col_value = list(game.genre)
game.genre = list(map(lambda x: x.lower(), col_value))

# %%
# now that strings are lowercase, let's run the duplicate pairs one more time

# from earlier
# paired duplicates between name and platform
test = game.duplicated(subset=['name', 'platform'], keep='last').reset_index()
test = test[test[0] == True]
dup_index = list(test['index'])
dup_index
# Out:
# []

# %%
# reformat the naming convention for

# build a dictionary to rename platforms
platform_dict = {'pcfx': 'pc-fx',
                 'gg': 'game_gear',
                 'tg16': 'turbo_grafx-16',
                 '3do': '3do',
                 'ws': 'wonderswan',
                 'scd': 'sega_cd',
                 'ng': 'neo_geo',
                 'gen': 'genesis',
                 'dc': 'dreamcast',
                 'gb': 'gameboy',
                 'nes': 'nintendo_entertainment_system',
                 '2600': '2600',
                 'wiiu': 'wii_u',
                 'sat': 'saturn',
                 'snes': 'super_nintendo_entertainment_system',
                 'xone': 'xbox_one',
                 'n64': 'nintendo_64',
                 'ps4': 'playstation_4',
                 'psv': 'playstation_vita',
                 '3ds': '3ds',
                 'gc': 'game_cube',
                 'gba': 'gameboy_advanced',
                 'xb': 'xbox',
                 'pc': 'computer',
                 'ps': 'playstation',
                 'psp': 'playstation_portable',
                 'x360': 'xbox_360',
                 'wii': 'wii',
                 'ps3': 'playstation_3',
                 'ds': 'ds',
                 'ps2': 'playstation_2',
                 }

# replace the old values with new values
game['platform'] = game['platform'].replace(platform_dict)

# %%
# create a brand column

# build a dictionary to map from the platform column
brand_dict = {'pc-fx': 'nec',
              'game_gear': 'sega',
              'turbo_grafx-16': 'nec',
              '3do': 'panasonic',
              'wonderswan': 'bandai',
              'sega_cd': 'sega',
              'neo_geo': 'snk',
              'genesis': 'sega',
              'dreamcast': 'sega',
              'gameboy': 'nintendo',
              'nintendo_entertainment_system': 'nintendo',
              '2600': 'atari',
              'wii_u': 'nintendo',
              'saturn': 'sega',
              'super_nintendo_entertainment_system': 'nintendo',
              'xbox_one': 'microsoft',
              'nintendo_64': 'nintendo',
              'playstation_4': 'sony',
              'playstation_vita': 'sony',
              '3ds': 'nintendo',
              'game_cube': 'nintendo',
              'gameboy_advanced': 'nintendo',
              'xbox': 'microsoft',
              'computer': 'computer',
              'playstation': 'sony',
              'playstation_portable': 'sony',
              'xbox_360': 'microsoft',
              'wii': 'nintendo',
              'playstation_3': 'sony',
              'ds': 'nintendo',
              'playstation_2': 'sony'}

game['brand'] = game['platform'].map(brand_dict)

# %%
# create a mobile column

# build a dictionary to map from the platform column
mobile_dict = {'pc-fx': 0,
               'game_gear': 1,
               'turbo_grafx-16': 0,
               '3do': 0,
               'wonderswan': 1,
               'sega_cd': 0,
               'neo_geo': 0,
               'genesis': 0,
               'dreamcast': 0,
               'gameboy': 1,
               'nintendo_entertainment_system': 0,
               '2600': 0,
               'wii_u': 1,
               'saturn': 0,
               'super_nintendo_entertainment_system': 0,
               'xbox_one': 0,
               'nintendo_64': 0,
               'playstation_4': 0,
               'playstation_vita': 1,
               '3ds': 1,
               'game_cube': 0,
               'gameboy_advanced': 1,
               'xbox': 0,
               'computer': 0,
               'playstation': 0,
               'playstation_portable': 1,
               'xbox_360': 0,
               'wii': 0,
               'playstation_3': 0,
               'ds': 1,
               'playstation_2': 0}

game['mobile'] = game['platform'].map(mobile_dict)

# %% [markdown]
# #### numeric columns
# ___
# release year, fill missing values<br>
# user_score, update scale to match critic_score<br>
# critic_score, replace placeholders<br>
# sales
# feature engineering, create total_sales column

# %%
# user_score, needs to be converted to float, it contains strings we should convert to missing
game['user_score'] = pd.to_numeric(game['user_score'], errors='coerce')

# %%
game.describe()
# Out:
#        year_of_release    na_sales    eu_sales    jp_sales  other_sales  \
# count       16440.0000  16709.0000  16709.0000  16709.0000   16709.0000
# mean         2006.4857      0.2632      0.1450      0.0776       0.0473
# std             5.8759      0.8135      0.5034      0.3089       0.1867
# min          1980.0000      0.0000      0.0000      0.0000       0.0000
# 25%          2003.0000      0.0000      0.0000      0.0000       0.0000
# 50%          2007.0000      0.0800      0.0200      0.0000       0.0100
# 75%          2010.0000      0.2400      0.1100      0.0400       0.0300
# max          2016.0000     41.3600     28.9600     10.2200      10.5700
#
#        critic_score  user_score      mobile
# count     8133.0000   7586.0000  16709.0000
# mean        68.9658      7.1253      0.3222
# std         13.9361      1.4997      0.4673
# min         13.0000      0.0000      0.0000
# 25%         60.0000      6.4000      0.0000
# 50%         71.0000      7.5000      0.0000
# 75%         79.0000      8.2000      1.0000
# max         98.0000      9.7000      1.0000

# %% [markdown]
# year of release: <br>
# mean < median, tail to the left (older) <br>
# 269 missing<br>
# categorical: fill with 'null'<br>
#
# critic score: <br>
# lots of missing<br>
#
# user_scoer:<br>
# different scale than critic score but approximately same sample size

# %%
# make user score 1-100 like critic score
game['user_score'] = game['user_score'] * 10

# %%
# what percent of data has a missing year
miss_year = game[game['year_of_release'].isna()]

sales_total = game['na_sales'].sum() + game['eu_sales'].sum() + \
    game['jp_sales'].sum() + game['other_sales'].sum()

missing_sales = miss_year['na_sales'].sum() + miss_year['eu_sales'].sum() + \
    miss_year['jp_sales'].sum() + miss_year['other_sales'].sum()

print(missing_sales / sales_total)
print(len(miss_year))
len(miss_year)/len(game)
# Out:
# 0.0111049865790422
# 269
# 0.016099108265006882

# %% [markdown]
# If this was sales data I would drop it. It is a categorical value so I will just fill missing with null. using the most frequent doesn't make a lot of sense here

# %%
# fill missing years
game['year_of_release'] = game['year_of_release'].fillna('null')

# %%
# create a new column for total sales
game['total_sales'] = game['na_sales'] + \
    game['eu_sales'] + game['jp_sales'] + game['other_sales']

# %%
game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16709 entries, 0 to 16714
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16709 non-null  object
#  1   platform         16709 non-null  object
#  2   year_of_release  16709 non-null  object
#  3   genre            16709 non-null  object
#  4   na_sales         16709 non-null  float64
#  5   eu_sales         16709 non-null  float64
#  6   jp_sales         16709 non-null  float64
#  7   other_sales      16709 non-null  float64
#  8   critic_score     8133 non-null   float64
#  9   user_score       7586 non-null   float64
#  10  rating           16709 non-null  object
#  11  brand            16709 non-null  object
#  12  mobile           16709 non-null  int64
#  13  total_sales      16709 non-null  float64
# dtypes: float64(7), int64(1), object(6)
# memory usage: 1.9+ MB

# %%
# save csv
game.to_csv('../processed_games.csv', index=False)
